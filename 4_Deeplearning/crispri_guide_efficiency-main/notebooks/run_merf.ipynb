# %%
## packages

import os
import random
import numpy as np
import pandas as pd

from merf.merf import MERF

from sklearn.model_selection import GroupKFold
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error
from scipy.stats import spearmanr
from src.utils import get_data, create_model_features, write_performance, reload_performance


import warnings
warnings.filterwarnings('ignore')

# %%
## set seeds
seed = 5555
random.seed(seed)
np.random.seed(seed)

# %%
def merf_core(model_type, X_train_val, X_test, y_train_val, y_test, y_median_train_val, y_median_test, features_gene, features_guide, performance, n_folds_inner, fold, plot_fold, group_ids_train_val, group_ids_test):

    X_train_val.reset_index(inplace=True,drop=True)
    X_test.reset_index(inplace=True,drop=True)
    y_train_val.reset_index(inplace=True,drop=True)
    y_test.reset_index(inplace=True,drop=True)
    y_median_test.reset_index(inplace=True,drop=True)
    
    #Divide Gene and Guide features for fixed effect and mixed effect
    X_train_val_guide = X_train_val[features_guide]
    X_train_val_gene = X_train_val[features_gene]
    
    X_test_guide = X_test[features_guide]
    X_test_gene = X_test[features_gene]
        
    
    predictions_train = np.zeros((X_train_val.shape[0], n_folds_inner))
    predictions_test = np.zeros((X_test.shape[0], n_folds_inner))
    
    gkf_inner = GroupKFold(n_splits=n_folds_inner)
    fold_inner = 0
    
    for index_train, index_val in gkf_inner.split(X_train_val, y_train_val, groups=group_ids_train_val):
        
        X_train_guide, X_val_guide = X_train_val_guide.iloc[index_train], X_train_val_guide.iloc[index_val]
        X_train_gene, X_val_gene = X_train_val_gene.iloc[index_train], X_train_val_gene.iloc[index_val]
        X_train_guide.reset_index(inplace=True,drop=True)
        X_val_guide.reset_index(inplace=True,drop=True)
        X_train_gene.reset_index(inplace=True,drop=True)
        X_val_gene.reset_index(inplace=True,drop=True)
        
        y_train, y_val = y_train_val.iloc[index_train], y_train_val.iloc[index_val]
        y_train.reset_index(inplace=True,drop=True)
        y_val.reset_index(inplace=True,drop=True)
        
        group_ids_train = [group_ids_train_val[i] for i in index_train]
        group_ids_val = [group_ids_train_val[i] for i in index_val]
        
        ## Train MERF model with chosen nonlinear model 
    
        if model_type == 'RF':
            model = RandomForestRegressor(n_estimators = 2000, max_features = 'log2', max_depth = 10, min_samples_split = 2, min_samples_leaf = 5, bootstrap = True, max_samples = 0.8, random_state = seed)
        elif model_type == 'GBM':    
            model = GradientBoostingRegressor(n_estimators = 2000, max_depth = 3, learning_rate = 0.01, random_state = seed)

        merf = MERF(model, max_iterations = 10)
        merf.fit(X_train_guide, X_train_gene, pd.Series(group_ids_train), y_train, X_val_guide, X_val_gene, pd.Series(group_ids_val), y_val)

        # predict and calculate MSE and spearman
        y_pred_train = merf.predict(X_train_val_guide, X_train_val_gene, pd.Series(group_ids_train_val))
        y_pred_test = merf.predict(X_test_guide, X_test_gene, pd.Series(group_ids_test))
        
        predictions_train[:,fold_inner] = y_pred_train
        predictions_test[:,fold_inner] = y_pred_test
        fold_inner +=1
        
    y_hat_train = predictions_train.mean(axis=1)
    y_hat_test = predictions_test.mean(axis=1)

    performance.iloc[fold,:] =  [round(mean_squared_error(y_train_val,y_hat_train),2), round(mean_squared_error(y_test,y_hat_test),2), 
                                 round(spearmanr(y_train_val,y_hat_train)[0],4), round(spearmanr(y_test,y_hat_test)[0],4)]
        
    return performance

# %%
def train_merf(model_type, X, Y, Y_median, features_gene, features_guide, gkf, group_ids, n_folds_outer, n_folds_inner, X_add = None, Y_add = None, Y_median_add = None, group_ids_add = None):

    fold = 0
    plot_fold = []
    performance = pd.DataFrame({'mse_train': np.zeros(n_folds_outer), 'mse_test': np.zeros(n_folds_outer), 
                                'spearmanR_train': np.zeros(n_folds_outer), 'spearmanR_test': np.zeros(n_folds_outer)})
    
    for index_train_val, index_test in gkf.split(X, Y, groups=group_ids):

        X_train_val, X_test = X.iloc[index_train_val], X.iloc[index_test]
        y_train_val, y_test = Y.iloc[index_train_val], Y.iloc[index_test]
        y_median_train_val, y_median_test = Y_median.iloc[index_train_val], Y_median.iloc[index_test]
        group_ids_train_val = [group_ids[i] for i in index_train_val]
        group_ids_test = [group_ids[i] for i in index_test]
        
        if (X_add is not None) & (Y_add is not None):
            
            gene_idx_filter = [i for i, gene in enumerate(group_ids_add) if gene in group_ids_test]
            group_ids_add_filtered = [i for j, i in enumerate(group_ids_add) if j not in gene_idx_filter]
        
            X_add_filtered = X_add.copy().drop(gene_idx_filter)
            X_add_filtered.reset_index(inplace=True,drop=True)
    
            Y_add_filtered = Y_add.copy().drop(gene_idx_filter)
            Y_add_filtered.reset_index(inplace=True,drop=True)
            
            Y_median_add_filtered = Y_median_add.copy().drop(gene_idx_filter)
            Y_median_add_filtered.reset_index(inplace=True,drop=True)
            
            X_train_val = pd.concat([X_train_val,X_add_filtered],axis=0)
            y_train_val = pd.concat([y_train_val,Y_add_filtered],axis=0)
            y_median_train_val = pd.concat([y_median_train_val,Y_median_add_filtered],axis=0)
            
            group_ids_train_val = group_ids_train_val + group_ids_add_filtered
        
        performance = merf_core(model_type, X_train_val, X_test, y_train_val, y_test, y_median_train_val, y_median_test, features_gene, features_guide, performance, n_folds_inner, fold, plot_fold, group_ids_train_val, group_ids_test)
        fold += 1
          
    print("---")
    print("Training with {}-fold grouped CV".format(n_folds_outer))
    performance_mean = pd.DataFrame({'mean':performance.mean(axis=0).round(3), 'variance':performance.var(axis=0).round(3)}).transpose()
    print(performance_mean)
    print(performance)
        
    return performance

# %%
output_performance = "../reports/performance_training/merf"

file_data_wang = '../datasets/data_wang.pickle'
file_one_hot_encoding_wang = '../datasets/one_hot_encoding_ML_wang.pickle'
file_kmer_wang = '../datasets/kmer_wang.pickle'

file_data_rousset_E18 = '../datasets/data_rousset_E18.pickle'
file_one_hot_encoding_rousset_E18 = '../datasets/one_hot_encoding_ML_rousset_E18.pickle'
file_kmer_rousset_E18 = '../datasets/kmer_rousset_E18.pickle'

file_data_rousset_E75 = '../datasets/data_rousset_E75.pickle'
file_one_hot_encoding_rousset_E75 = '../datasets/one_hot_encoding_ML_rousset_E75.pickle'
file_kmer_rousset_E75 = '../datasets/kmer_rousset_E75.pickle'

# %%
## setup parameters

n_folds_outer = 5
n_folds_inner = 5
features_gene_guide = ["gene_length", "gene_GC_content", "distance_operon", "operon_downstream_genes", "ess_gene_operon", "gene_expression_min", "gene_expression_max",
               "guide_GC_content", "distance_start_codon", "homopolymers", "MFE_hybrid_full", "MFE_hybrid_seed", "MFE_homodimer_guide", "MFE_monomer_guide", 
               "off_target_90_100", "off_target_80_90", "off_target_70_80", "off_target_60_70"]

features_gene = ["gene_length", "gene_GC_content", "distance_operon", "operon_downstream_genes", "ess_gene_operon", "gene_expression_min", "gene_expression_max"]

features_guide = ["guide_GC_content", "distance_start_codon", "homopolymers", "MFE_hybrid_full", "MFE_hybrid_seed", "MFE_homodimer_guide", "MFE_monomer_guide", "off_target_90_100", "off_target_80_90", "off_target_70_80", "off_target_60_70"]

datasets = ["wang_orig_guide-genes","wang_orig_guide","wang_median-sub_guide-genes","wang_median-sub_guide","wang_rank_guide-genes","wang_rank_guide",
            "rousset_E18_orig_guide-genes","rousset_E18_orig_guide","rousset_E18_median-sub_guide-genes","rousset_E18_median-sub_guide","rousset_E18_rank_guide-genes","rousset_E18_rank_guide",
            "rousset_E75_orig_guide-genes","rousset_E75_orig_guide","rousset_E75_median-sub_guide-genes","rousset_E75_median-sub_guide","rousset_E75_rank_guide-genes","rousset_E75_rank_guide",
            "wang_rousset_E18_orig_guide-genes","wang_rousset_E18_orig_guide","wang_rousset_E18_median-sub_guide-genes","wang_rousset_E18_median-sub_guide","wang_rousset_E18_rank_guide-genes","wang_rousset_E18_rank_guide",
            "wang_rousset_E75_orig_guide-genes","wang_rousset_E75_orig_guide","wang_rousset_E75_median-sub_guide-genes","wang_rousset_E75_median-sub_guide","wang_rousset_E75_rank_guide-genes","wang_rousset_E75_rank_guide",
            "wang_rousset_E18_rousset_E75_orig_guide-genes","wang_rousset_E18_rousset_E75_orig_guide","wang_rousset_E18_rousset_E75_median-sub_guide-genes","wang_rousset_E18_rousset_E75_median-sub_guide","wang_rousset_E18_rousset_E75_rank_guide-genes","wang_rousset_E18_rousset_E75_rank_guide"]

models = ["RF", "GBM"]

# %%
## setup performance tables
perf = pd.DataFrame(columns = models, index = datasets)

# mse_train, mse_test, spearmanR_train, spearmanR_test
performance_table = [perf,perf,perf,perf]
performance_table = reload_performance(output_performance)

# %%
## load data

data_wang = get_data(file_data_wang)
one_hot_encoding_wang = get_data(file_one_hot_encoding_wang)
kmer_wang = get_data(file_kmer_wang)

data_rousset_E18 = get_data(file_data_rousset_E18)
one_hot_encoding_rousset_E18 = get_data(file_one_hot_encoding_rousset_E18)
kmer_rousset_E18 = get_data(file_kmer_rousset_E18)

data_rousset_E75 = get_data(file_data_rousset_E75)
one_hot_encoding_rousset_E75 = get_data(file_one_hot_encoding_rousset_E75)
kmer_rousset_E75 = get_data(file_kmer_rousset_E75)

# %%
## Create X and Y variables

model_features_wang = create_model_features(data_wang,one_hot_encoding_wang,kmer_wang,features_gene_guide,features_guide)
model_features_rousset_E18 = create_model_features(data_rousset_E18,one_hot_encoding_rousset_E18,kmer_rousset_E18,features_gene_guide,features_guide)
model_features_rousset_E75 = create_model_features(data_rousset_E75,one_hot_encoding_rousset_E75,kmer_rousset_E75,features_gene_guide,features_guide)

# %%
# %matplotlib
models_skip = ["RF"]

for model in models:
    
    if model in models_skip:
        print("skipped: " + model)
        continue
    else:
        print("---")
        print(model)


        for dataset in datasets:

            # get correct dataset
            if "wang_rousset_E18" in dataset:
                print(dataset)
                modl_features = model_features_wang
                model_features_add = model_features_rousset_E18
                X_add = model_features_add["X_gene_guide"].copy()
                Y_add = model_features_add["Y_orig"].copy()
                Y_median_add = model_features_add["Y_median_sub"].copy()
                group_ids_add = model_features_add["geneid"]

            elif "wang" in dataset:
                print(dataset)
                model_features = model_features_wang
                X_add = None
                Y_add = None
                Y_median_add = None
                group_ids_add = None

            elif "rousset_E18" in dataset:
                print(dataset)
                model_features = model_features_rousset_E18
                X_add = None
                Y_add = None
                Y_median_add = None
                group_ids_add = None

            elif "rousset_E75" in dataset:
                print(dataset)
                model_features = model_features_rousset_E75
                X_add = None
                Y_add = None
                Y_median_add = None
                group_ids_add = None


            performance = train_merf(model, model_features["X_gene_guide"].copy(), model_features["Y_orig"].copy(), model_features["Y_median_sub"].copy(), 
                                     features_gene, features_guide, GroupKFold(n_splits=n_folds_outer), model_features["geneid"], n_folds_outer, n_folds_inner,
                                     X_add = X_add, Y_add = Y_add, Y_median_add = Y_median_add, group_ids_add = group_ids_add)


            performance_table = write_performance(performance_table, performance, model, dataset, outfiles = output_performance)
# Out:
# Using matplotlib backend: agg
# skipped: RF
# ---
# GBM
# wang_orig_guide-genes
# INFO     [merf.py:307] Training GLL is 3877.56301795128 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.122134649094318 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3592.4942981304403 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.831437258602628 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3372.6004853985137 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.862252857558604 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3158.048925398552 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.827856554442818 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2947.4908222886556 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.854831164527326 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2743.127962102622 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.821543295343552 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2518.6663429918954 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.865042204762518 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2324.982499514376 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.8455259686956245 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2128.769194011528 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.8454164362188745 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1912.9097722695842 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.866117784449855 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3980.1171434256657 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.411777346793157 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3627.3974171021246 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.292304134852759 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3401.798665858336 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.3638370339558 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3166.22162506916 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.40074268988622 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2953.9108778847008 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.412665192353921 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2741.4356941022347 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.404821666319608 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2529.1929981336816 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.399848096827073 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2327.743574376873 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.396117888023246 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2126.656768282327 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.401767562118312 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1928.085340392664 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.405463475580637 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3862.9461285078505 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.115964898666323 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3551.278946515619 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.8511295768563505 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3355.0702230178 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.868830057077974 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3120.6181612617465 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.8963205061904045 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2914.9137638394354 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.899334339145103 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2694.9241953729274 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.8983053119130755 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2486.4837039384583 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.909955828746221 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2279.9672690395505 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.893805384949648 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2079.5482669926296 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.905612465360317 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1891.4905232109745 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.896204231134294 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3961.613661685686 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.116112007684293 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3597.4636404363528 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.970732533200984 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3356.2526212594516 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.888536344591146 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3136.4824743699646 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.860311136990939 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2940.768486867767 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.855026389335521 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2735.339016146859 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.829822941392627 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2526.857669899135 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.844542467768359 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2321.8625316918733 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.830148102566755 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2112.9555172953724 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.843525386062835 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1921.217499537236 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.834707070101402 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4097.294252939997 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 5.899134977465481 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3754.2898232637526 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.119732615476249 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3510.101658117841 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.156269669337531 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3298.082235579633 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.200473665152788 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3091.5788443442975 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.20213957148612 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2874.073891060893 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.217005986035803 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2663.5977997485775 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.220187293936572 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2466.0279818590952 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.211926010008975 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2264.1731847902806 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.22591867867133 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2069.2933572366046 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.224689713263958 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4128.756361587073 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.443135801443352 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3833.902047777571 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.2726741891859685 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3591.592561581231 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.210733378312547 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3372.8282416688194 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.2015916765472445 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3157.7605498561243 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.210445574894504 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2960.4725080110284 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.182461539576705 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2742.548209336263 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.183947132899885 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2542.144618408322 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.177490832464778 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2351.8161864009953 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.200258372462858 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2158.682219175079 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.171142526723136 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4137.307922860949 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.794497246988118 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3795.8114672828556 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.662830892349659 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3567.3599661525873 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.6404989117342375 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3349.9657317901274 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.60549007687529 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3116.1390488901325 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.621420598511529 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2914.205731199031 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.611326241923411 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2702.4890772422655 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.59915021254172 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2504.876809610176 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.613022715650221 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2295.310939304736 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.586205847196028 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2099.1643465206607 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.588233170006065 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4029.1230641384645 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.399029241757842 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3664.31167904444 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 7.3308874802665445 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3436.221945873353 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 7.255198412014374 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3221.5959392461227 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 7.234376306969216 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3005.0035964068798 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 7.2664066165381165 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2800.345776687397 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 7.268407186194905 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2588.645175083232 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 7.2850293956886185 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2383.9079112386266 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 7.305462941415097 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2179.132700566115 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 7.284628884462871 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1986.4903726412495 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 7.294510002019709 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4157.255686649744 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.2971189347250665 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3829.8456678218686 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.401031150780608 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3609.5606223419786 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.4366479781327 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3387.4006890383434 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.461941896107536 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3160.191676828776 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.4420196172549185 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2948.0263875929327 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.468960970175097 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2729.274379436108 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.452266160903231 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2524.0388855725573 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.451135848783517 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2317.749725193853 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.4614241706685 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2114.989642609721 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.459910954412011 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4210.109321708393 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.991080711309809 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3826.13123223154 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.66475469170265 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3570.7438662162126 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.674982728371256 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3328.2781666101055 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.6686399374563505 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3110.2996117035527 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.707709001382273 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2899.2358806704233 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.706976392477324 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2700.6720860982714 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.670234737470432 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2494.6048996777677 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.68745448967263 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2290.628265109439 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.703983029044329 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2088.0353465241274 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.698859392225779 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4062.8772414322025 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 5.958244055237395 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3627.1888654554464 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.019739240593111 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3401.5622024507293 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.043167277870968 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3177.17859572565 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.048609915327297 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2967.117817495452 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.012286251717925 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2755.605158445793 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.036288357539736 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2550.2816462145042 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.0214390165564 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2348.1396712112355 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.016705142337627 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2148.5365206298093 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.017655633940264 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1953.6416491130553 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.022586305717058 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4128.73004527896 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.171683408927417 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3781.2288960842116 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.120465667764573 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3546.1258432882855 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.130365463362231 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3321.2179890479256 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.135265553206957 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3112.0573142288217 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.139644399310863 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2894.9106973768303 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.103268765689585 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2694.5523734608923 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.134209222305163 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2487.8966504246278 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.124217854501975 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2294.235027658078 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.1088014451479955 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2093.8944936953344 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.133351207499589 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3992.2144888429093 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.966533853164066 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3652.1201353223337 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.915769244489875 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3428.769983961829 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.9212184080737496 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3217.071895210422 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.902105014688372 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3001.893013481342 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.92494401618999 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2795.458392237874 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.910879501904289 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2578.9868865058666 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.917766118699088 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2373.6308471500765 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.927010486815927 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2171.134684981893 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.9239872093412265 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1979.0632368188246 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.902799611458672 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4019.4329095903327 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.905130912998924 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3662.5188031876432 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.729022041298249 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3450.2078444598455 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.728845354384249 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3219.5637873634078 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.7376832084319105 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3004.6708585214305 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.727236634513809 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2795.685015730959 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.726445323002204 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2592.1984694093353 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.718293727786752 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2385.273186506463 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.728665369768394 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2188.9765449988518 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.738984994618345 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1985.5997799190616 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.734250159159754 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4003.796821089321 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.686950950007036 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3724.2647483390933 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.719767353757776 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3484.9566724874912 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.715429745469896 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3269.8738063368896 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.722706496673105 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3054.6286595794745 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.743375230231196 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2839.0625477942604 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.740668668152363 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2627.2344250736637 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.762249519217315 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2430.5450657112215 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.730538377231267 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2219.4465080092396 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.766125769900977 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2030.7554887178567 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.721019864527388 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4177.608702559058 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.3529864336376365 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3785.8681372212172 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.330591453211494 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3551.2933119048485 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.279994156961589 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3329.33988248227 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.278986655681484 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3121.653589192026 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.272184604599749 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2911.580121595595 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.24755075383128 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2701.084179675442 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.253364342959955 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2494.3614979708095 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.261549367625934 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2298.816764914457 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.254124803822405 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2097.8481798225803 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.248067244112579 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4088.0858619019614 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.261562290531554 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3814.173907215795 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.913184757805242 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3602.1919314313495 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.829312216502437 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3396.4301928074738 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.801105058586908 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3171.575508114489 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.793428994602405 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2962.2156645077102 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.766202682606627 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2742.277851499589 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.742703722810775 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2531.3507284663206 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.776801718711087 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2339.6006039359286 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.772732417938483 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2160.489917483009 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.754855762640434 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4029.0896792561302 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.945076914664355 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3704.096475287885 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 7.880740629355615 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3460.587641924492 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 7.931057762134734 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3261.3115885479297 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 7.955139762813053 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3044.587988079836 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 7.9607722515211305 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2841.028094832696 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 7.974195964411409 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2638.995769525938 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 7.93258121324375 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2426.288067227627 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 7.976991598972141 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2231.437965937533 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 7.964362041935256 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2037.272246386948 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 7.960829702594023 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4238.046384432585 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.029979594964699 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3943.4129364043783 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.924361243418238 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3738.8179178153355 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.929210583661328 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3522.2166317893134 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.900452000508797 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3305.0566556127274 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.932174168438162 at iteration 5.
# INFO     [merf.py:307] Training GLL is 3096.159152019711 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.927588965418826 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2883.8442470828886 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.9152988328279905 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2681.3422584152627 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.935056942478445 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2477.8094709877 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.934307914859079 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2278.8603289976254 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.917135775719625 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4039.5816296896087 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.229687116116192 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3684.1101617477525 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 7.229744516963291 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3465.536749792824 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 7.240093719262178 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3246.4108711781464 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 7.262328329143656 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3041.888815279651 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 7.263165171449248 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2827.897429383588 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 7.274213883297115 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2622.7845259511723 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 7.278493599184874 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2411.6619234496184 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 7.274795279060717 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2211.395859532425 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 7.278312951695655 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2010.5144372086393 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 7.26860986805563 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4067.2346191634792 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.661207818814701 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3752.1674613211244 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.438592490194811 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3543.449646451817 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.501089559101191 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3321.2826225637114 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.506073221361943 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3105.1512854068123 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.501664681679579 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2894.9404971392123 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.516751813949048 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2691.281392472132 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.479605566175504 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2480.808484505085 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.508679633720645 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2278.9905746515437 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.506778836773799 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2072.6819553865075 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.513992258327088 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4135.9607602924525 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.249768844343383 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3785.974131707576 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.154915603724576 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3554.084922917915 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.117228566229825 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3332.128638708139 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.138998696309971 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3119.7855901739213 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.14325140516913 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2910.1217652726664 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.116792787488709 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2689.142430541006 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.136747059238545 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2493.2325215909796 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.1393712477584375 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2294.5071678056233 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.128389561874387 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2095.5249339061725 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.139411134660927 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3967.721725019045 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.861636005920406 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3635.5755406372455 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.630323973535352 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3448.1034027972933 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.596095947586919 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3227.415990413476 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.588269028092774 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2997.1328115507345 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.613556643014633 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2786.1155099306698 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.622702090344135 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2571.75775250005 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.623716819823387 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2360.8756305057072 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.634979231120312 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2158.9726097942066 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.606336292517364 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1956.4865881929577 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.631552934174862 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4099.342413825982 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.3823609821330685 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3779.6452068775984 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.398939961854084 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3571.009912168635 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.3932990679823964 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3348.9663532135783 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.39822797250206 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3150.3563683989514 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.40650627093834 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2936.384115286666 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.41799856032578 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2710.6364009077474 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.386932972231825 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2508.5843720130883 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.418738865380288 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2317.8784666655833 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.415870052819121 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2108.2679110469367 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.414304396976187 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4141.883285626712 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 5.903829322294595 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3763.609488346814 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.690736994737525 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3537.0693362018997 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.704885673642903 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3300.834516300783 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.711854899316854 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3093.613210024571 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.723368890602511 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2882.1331539581747 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.726109628400268 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2663.321023324582 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.726791702858388 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2468.390729486078 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.736814268173559 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2267.157299162288 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.720046474883305 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2060.8941386349707 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.699469329055128 at iteration 10.
# ---
# Training with 5-fold grouped CV
#           mse_train  mse_test  spearmanR_train  spearmanR_test
# mean          2.798     6.442            0.743           0.135
# variance      0.007     0.712            0.000           0.001
#    mse_train  mse_test  spearmanR_train  spearmanR_test
# 0       2.68      6.88           0.7549          0.1621
# 1       2.86      5.83           0.7432          0.1296
# 2       2.75      6.97           0.7320          0.0916
# 3       2.89      5.28           0.7527          0.1174
# 4       2.81      7.25           0.7301          0.1739
# wang_orig_guide
# INFO     [merf.py:307] Training GLL is 3877.56301795128 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.122134649094318 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3592.4942981304403 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.831437258602628 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3372.6004853985137 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.862252857558604 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3158.048925398552 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.827856554442818 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2947.4908222886556 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.854831164527326 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2743.127962102622 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.821543295343552 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2518.6663429918954 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.865042204762518 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2324.982499514376 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.8455259686956245 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2128.769194011528 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.8454164362188745 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1912.9097722695842 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.866117784449855 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3980.1171434256657 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.411777346793157 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3627.3974171021246 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.292304134852759 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3401.798665858336 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.3638370339558 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3166.22162506916 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.40074268988622 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2953.9108778847008 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.412665192353921 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2741.4356941022347 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.404821666319608 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2529.1929981336816 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.399848096827073 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2327.743574376873 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.396117888023246 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2126.656768282327 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.401767562118312 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1928.085340392664 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.405463475580637 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3862.9461285078505 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.115964898666323 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3551.278946515619 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.8511295768563505 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3355.0702230178 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.868830057077974 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3120.6181612617465 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.8963205061904045 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2914.9137638394354 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.899334339145103 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2694.9241953729274 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.8983053119130755 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2486.4837039384583 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.909955828746221 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2279.9672690395505 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.893805384949648 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2079.5482669926296 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.905612465360317 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1891.4905232109745 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.896204231134294 at iteration 10.
# INFO     [merf.py:307] Training GLL is 3961.613661685686 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.116112007684293 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3597.4636404363528 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.970732533200984 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3356.2526212594516 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.888536344591146 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3136.4824743699646 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.860311136990939 at iteration 4.
# INFO     [merf.py:307] Training GLL is 2940.768486867767 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.855026389335521 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2735.339016146859 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.829822941392627 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2526.857669899135 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.844542467768359 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2321.8625316918733 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.830148102566755 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2112.9555172953724 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.843525386062835 at iteration 9.
# INFO     [merf.py:307] Training GLL is 1921.217499537236 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.834707070101402 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4097.294252939997 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 5.899134977465481 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3754.2898232637526 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.119732615476249 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3510.101658117841 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.156269669337531 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3298.082235579633 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.200473665152788 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3091.5788443442975 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.20213957148612 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2874.073891060893 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.217005986035803 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2663.5977997485775 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.220187293936572 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2466.0279818590952 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.211926010008975 at iteration 8.
# INFO     [merf.py:307] Training GLL is 2264.1731847902806 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.22591867867133 at iteration 9.
# INFO     [merf.py:307] Training GLL is 2069.2933572366046 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.224689713263958 at iteration 10.
# INFO     [merf.py:307] Training GLL is 4128.756361587073 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.443135801443352 at iteration 1.
# INFO     [merf.py:307] Training GLL is 3833.902047777571 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.2726741891859685 at iteration 2.
# INFO     [merf.py:307] Training GLL is 3591.592561581231 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.210733378312547 at iteration 3.
# INFO     [merf.py:307] Training GLL is 3372.8282416688194 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.2015916765472445 at iteration 4.
# INFO     [merf.py:307] Training GLL is 3157.7605498561243 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.210445574894504 at iteration 5.
# INFO     [merf.py:307] Training GLL is 2960.4725080110284 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.182461539576705 at iteration 6.
# INFO     [merf.py:307] Training GLL is 2742.548209336263 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.183947132899885 at iteration 7.
# INFO     [merf.py:307] Training GLL is 2542.144618408322 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.177490832464778 at iteration 8.
# ...
# INFO     [merf.py:307] Training GLL is 3435.933454231017 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 7.374713190033785 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3206.244987645387 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 7.366871357724037 at iteration 10.
# INFO     [merf.py:307] Training GLL is 5931.366202296258 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.9528196273405305 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5473.707251118848 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.861263330262062 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5177.919194305448 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.857028768112145 at iteration 3.
# INFO     [merf.py:307] Training GLL is 4894.379169338168 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.850242796309918 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4637.348808739934 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.84698176450294 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4375.1274825809705 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.844305655692351 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4129.345758972505 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.8474143245178185 at iteration 7.
# INFO     [merf.py:307] Training GLL is 3885.9358932421696 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.840543191199329 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3654.6388205208827 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.8311494853590045 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3437.069568931981 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.845516323309223 at iteration 10.
# INFO     [merf.py:307] Training GLL is 5991.93501608694 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.429822922924353 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5477.651635712057 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.47347913345389 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5183.736975317858 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.5113893801056575 at iteration 3.
# INFO     [merf.py:307] Training GLL is 4927.200185583326 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.513000440868806 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4661.872890170333 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.491691569895867 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4425.451902446891 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.52650215592757 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4183.89398854881 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.528352522965044 at iteration 7.
# INFO     [merf.py:307] Training GLL is 3953.5559597068623 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.512688033329878 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3724.73372900603 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.535985586288681 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3493.502657556797 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.527875666817067 at iteration 10.
# INFO     [merf.py:307] Training GLL is 6122.944200853678 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.069865313182524 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5697.39324901731 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.972043344974626 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5420.537396340666 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.877344839162833 at iteration 3.
# INFO     [merf.py:307] Training GLL is 5145.496333714142 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.884184162604264 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4883.919225834481 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.8906320890647015 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4628.804579813564 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.887847959780811 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4382.635700017906 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.880797123806867 at iteration 7.
# INFO     [merf.py:307] Training GLL is 4146.37692405952 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.898824408550666 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3904.7965900685813 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.900828401208176 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3682.331343069458 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.912905153346587 at iteration 10.
# INFO     [merf.py:307] Training GLL is 6022.49026767349 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.236956954398462 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5619.0515355165435 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.113611807007345 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5333.814087583867 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.126755822732424 at iteration 3.
# INFO     [merf.py:307] Training GLL is 5049.079561521838 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.12367411517513 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4800.76934128676 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.12784474487373 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4531.292205532677 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.121963240534747 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4281.6557543099225 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.140080702268898 at iteration 7.
# INFO     [merf.py:307] Training GLL is 4042.7948386254143 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.131076026288119 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3811.8426277382027 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.13817869403501 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3580.005432034803 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.1417668990908245 at iteration 10.
# INFO     [merf.py:307] Training GLL is 6005.240929928421 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.233884452191663 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5581.018848157551 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.056521141519731 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5300.405689499285 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.074455133313179 at iteration 3.
# INFO     [merf.py:307] Training GLL is 5024.63631640478 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.079159513032757 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4758.936708674355 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.07689510919337 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4496.057601168239 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.063486467250477 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4262.507622191072 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.054679392662299 at iteration 7.
# INFO     [merf.py:307] Training GLL is 4030.9865807961696 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.060627002462852 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3791.7335208156455 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.065730340796166 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3569.5919752785535 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.072161685582268 at iteration 10.
# INFO     [merf.py:307] Training GLL is 6047.175768850141 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.3696448382754305 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5584.963560718343 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.27442909378221 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5302.375115750121 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.350733497301317 at iteration 3.
# INFO     [merf.py:307] Training GLL is 5010.310999332675 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.362333896017028 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4740.9850512829225 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.367849221090698 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4478.37793013644 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.361928338571167 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4244.83157389946 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.363005574114615 at iteration 7.
# INFO     [merf.py:307] Training GLL is 4010.1861367659917 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.3558484924303515 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3779.620020110145 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 6.385997023508056 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3543.0572580106727 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 6.374507490146626 at iteration 10.
# ---
# Training with 5-fold grouped CV
#           mse_train  mse_test  spearmanR_train  spearmanR_test
# mean          2.954     6.406            0.739           0.132
# variance      0.003     0.676            0.000           0.001
#    mse_train  mse_test  spearmanR_train  spearmanR_test
# 0       2.86      6.88           0.7478          0.1459
# 1       2.97      5.81           0.7419          0.1326
# 2       2.96      6.89           0.7311          0.0863
# 3       3.00      5.27           0.7450          0.1180
# 4       2.98      7.18           0.7313          0.1749
# wang_rousset_E18_rousset_E75_orig_guide
# INFO     [merf.py:307] Training GLL is 5701.098188135601 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 7.285874809326848 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5254.587645995076 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 7.182457609216132 at iteration 2.
# INFO     [merf.py:307] Training GLL is 4967.933916754606 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 7.153430877630719 at iteration 3.
# INFO     [merf.py:307] Training GLL is 4699.046537669024 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 7.126878544626028 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4439.900801093334 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 7.113920287283835 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4180.416448242112 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 7.119139299073636 at iteration 6.
# INFO     [merf.py:307] Training GLL is 3928.1182006534764 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 7.119395100780539 at iteration 7.
# INFO     [merf.py:307] Training GLL is 3677.6064898799973 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 7.129333514510492 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3440.609615810775 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 7.145681332193135 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3230.5858066107285 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 7.129719648860311 at iteration 10.
# INFO     [merf.py:307] Training GLL is 5908.522131712531 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.067392508673264 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5432.197637049465 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.951364346371968 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5160.734666798482 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.9282561466395896 at iteration 3.
# INFO     [merf.py:307] Training GLL is 4899.50030993841 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.926853184959237 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4633.463710244921 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.925391604155079 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4384.567045875071 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.92903870073119 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4140.392215778019 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.934567710316351 at iteration 7.
# INFO     [merf.py:307] Training GLL is 3909.499717561856 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.929863359047586 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3680.3032148185757 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.92944097153592 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3463.6787703180776 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.932290868079034 at iteration 10.
# INFO     [merf.py:307] Training GLL is 5973.808056096851 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.032001071026297 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5470.035834199607 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 5.812506524409473 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5167.301357013287 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 5.763415214599679 at iteration 3.
# INFO     [merf.py:307] Training GLL is 4881.627379410986 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 5.74978337779097 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4618.808226083934 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 5.761643192508506 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4354.825789740339 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 5.784566938992526 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4113.177233466536 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 5.775440002775778 at iteration 7.
# INFO     [merf.py:307] Training GLL is 3870.52873599634 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 5.782983744514663 at iteration 8.
# INFO     [merf.py:307] Training GLL is 3649.301815716385 at iteration 9.
# INFO     [merf.py:328] Validation MSE Loss is 5.7868631850418915 at iteration 9.
# INFO     [merf.py:307] Training GLL is 3431.5647992695854 at iteration 10.
# INFO     [merf.py:328] Validation MSE Loss is 5.8033619901290665 at iteration 10.
# INFO     [merf.py:307] Training GLL is 5888.22219772385 at iteration 1.
# INFO     [merf.py:328] Validation MSE Loss is 6.439071940129637 at iteration 1.
# INFO     [merf.py:307] Training GLL is 5459.652917528414 at iteration 2.
# INFO     [merf.py:328] Validation MSE Loss is 6.316944267571665 at iteration 2.
# INFO     [merf.py:307] Training GLL is 5180.456986261288 at iteration 3.
# INFO     [merf.py:328] Validation MSE Loss is 6.2958186477324976 at iteration 3.
# INFO     [merf.py:307] Training GLL is 4906.584384687365 at iteration 4.
# INFO     [merf.py:328] Validation MSE Loss is 6.303475219000812 at iteration 4.
# INFO     [merf.py:307] Training GLL is 4637.984265271612 at iteration 5.
# INFO     [merf.py:328] Validation MSE Loss is 6.306310523365904 at iteration 5.
# INFO     [merf.py:307] Training GLL is 4384.1363935555455 at iteration 6.
# INFO     [merf.py:328] Validation MSE Loss is 6.304253372448165 at iteration 6.
# INFO     [merf.py:307] Training GLL is 4138.8844564166275 at iteration 7.
# INFO     [merf.py:328] Validation MSE Loss is 6.313199315922475 at iteration 7.
# INFO     [merf.py:307] Training GLL is 3906.1145458806986 at iteration 8.
# INFO     [merf.py:328] Validation MSE Loss is 6.312257832707613 at iteration 8.
